# %% [markdown]
# <a href="https://colab.research.google.com/github/keerthana901/CIE2/blob/main/CIE_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('/content/mtcars (2).csv')
df
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
x = df[['mpg']]
x
# Out:
#      mpg
# 0   21.0
# 1   21.0
# 2   22.8
# 3   21.4
# 4   18.7
# 5   18.1
# 6   14.3
# 7   24.4
# 8   22.8
# 9   19.2
# 10  17.8
# 11  16.4
# 12  17.3
# 13  15.2
# 14  10.4
# 15  10.4
# 16  14.7
# 17  32.4
# 18  30.4
# 19  33.9
# 20  21.5
# 21  15.5
# 22  15.2
# 23  13.3
# 24  19.2
# 25  27.3
# 26  26.0
# 27  30.4
# 28  15.8
# 29  19.7
# 30  15.0
# 31  21.4

# %%
y = df[['hp']]
y
# Out:
#      hp
# 0   110
# 1   110
# 2    93
# 3   110
# 4   175
# 5   105
# 6   245
# 7    62
# 8    95
# 9   123
# 10  123
# 11  180
# 12  180
# 13  180
# 14  205
# 15  215
# 16  230
# 17   66
# 18   52
# 19   65
# 20   97
# 21  150
# 22  150
# 23  245
# 24  175
# 25   66
# 26   91
# 27  113
# 28  264
# 29  175
# 30  335
# 31  109

# %%
sns.scatterplot(data=df,x=df['mpg'],y =df['hp'])
plt.show()

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
#      mpg
# 26  26.0
# 20  21.5
# 13  15.2
# 24  19.2
# 5   18.1
# 17  32.4
# 8   22.8
# 30  15.0
# 25  27.3
# 23  13.3
# 1   21.0
# 31  21.4
# 6   14.3
# 4   18.7
# 18  30.4
# 29  19.7
# 19  33.9
# 9   19.2
# 7   24.4
# 27  30.4
# 3   21.4
# 0   21.0
# 21  15.5
# 15  10.4
# 12  17.3

# %%
x_test
# Out:
#      mpg
# 11  16.4
# 22  15.2
# 10  17.8
# 2   22.8
# 16  14.7
# 14  10.4
# 28  15.8

# %%
y_train
# Out:
#      hp
# 26   91
# 20   97
# 13  180
# 24  175
# 5   105
# 17   66
# 8    95
# 30  335
# 25   66
# 23  245
# 1   110
# 31  109
# 6   245
# 4   175
# 18   52
# 29  175
# 19   65
# 9   123
# 7    62
# 27  113
# 3   110
# 0   110
# 21  150
# 15  215
# 12  180

# %%
y_test
# Out:
#      hp
# 11  180
# 22  150
# 10  123
# 2    93
# 16  230
# 14  205
# 28  264

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred =lr.predict(x_test)
x_pred =lr.predict(x_train)
print('y_pred',y_pred)
print('x_pred',x_pred)
# Out:
# y_pred [[180.11574726]
#  [190.67227829]
#  [167.79979439]
#  [123.81424842]
#  [195.07083289]
#  [232.89840242]
#  [185.39401277]]
# x_pred [[ 95.663499  ]
#  [135.25049037]
#  [190.67227829]
#  [155.48384151]
#  [165.16066163]
#  [ 39.36200015]
#  [123.81424842]
#  [192.43170013]
#  [ 84.22725704]
#  [207.38678576]
#  [139.64904497]
#  [136.13020129]
#  [198.58967656]
#  [159.88239611]
#  [ 56.95621854]
#  [151.08528692]
#  [ 26.16633636]
#  [155.48384151]
#  [109.73887371]
#  [ 56.95621854]
#  [136.13020129]
#  [139.64904497]
#  [188.03314553]
#  [232.89840242]
#  [172.19834898]]

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,root_mean_squared_error
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test,y_pred)

print('mean_absolute_error',mae)
print('mean_squared_error',mse)
print('root_mean_squared_error',rmse)
print('r2_score',r2)
# Out:
# mean_absolute_error 36.83366073000569
# mean_squared_error 1826.8651288378394
# root_mean_squared_error 42.74184283390036
# r2_score 0.41518546454481586

# %%
plt.scatter(x_train,y_train,color='red')
plt.plot(x_train,x_pred,color='blue')
plt.title('MPG VS HP (training data)')
plt.xlabel('HP')
plt.ylabel('MPG')
plt.show()
